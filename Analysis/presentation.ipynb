# %% [markdown]
# <!-- Inline CSS: put this as the first Markdown cell -->
# <style>
# /* cover all common selectors so theme cannot override */
# .reveal .slides section h1,
# .reveal h1,
# .reveal .slides section .slide h1 {
#   text-align: center !important;
#   margin: 0.2em 0 0.6em 0;
#   font-weight: 700;
#   letter-spacing: 0.02em;
#   color: #268bd2; /* solarized blue */
# }
#
# /* title slide specific */
# .reveal .slides section.title-slide h1 {
#   text-align: center !important;
# }
#
# /* subtitle */
# .reveal .slides section h2,
# .reveal h2 {
#   text-align: center !important;
#   font-weight: 400;
#   color: #586e75;
# }
#
# /* fragments fade-in */
# .reveal .fragment { opacity: 0; transition: opacity 350ms ease; }
# .reveal .fragment.visible { opacity: 1; }
# </style>

# %% [markdown]
# <!-- .slide: data-background="#fdf6e3" data-transition="fade" -->
#
# <h1 style="text-align:center;">PREDICTIVE ANALYTICS</h1>
# <p style="text-align:center;">Vijayakumar P</p>

# %% [markdown]
# <h1 style="text-align:center;">OUTLINE</h1>
#
# - Introduction
# - Examples
# - Model
# - Results
# - Conclusion

# %% [markdown]
# <!-- .slide: data-background="#fdf6e3" data-transition="fade" -->
#
# <h1 style="text-align:center;">Introduction</h1>
#
# Predictive analytics is a powerful approach that leverages **historical data, statistical algorithms, and machine learning** to forecast future outcomes.
#
# - By identifying patterns and trends within existing data, organisations can make informed, proactive decisions.
# - Predictive analytics is widely applied across industries such as finance, healthcare, retail, telecommunications, and manufacturing

# %% [markdown]
# ![](Analogy_predictive_analytics.png)

# %% [markdown]
# <!-- .slide: data-background="#fdf6e3" data-transition="fade" -->
#
# <h1 style="text-align:center;">The Process of Prediction</h1>
# <div style="text-align:center;">
#   <img src="process_pa.png" alt="Flowchart" style="width:45%; height:50%;">
# </div>

# %% [markdown]
# ## 1. Define the Goal
# The first step is to clearly define the business problem you want to solve. This is crucial because it guides the entire process.
#
# - Are you trying to predict which customers are likely to stop using your service? Or do you want to forecast product demand for the next quarter?
# - A specific question leads to a specific and useful answer.

# %% [markdown]
# ## 2. Data Collection and Preparation
# Once the goal is set, relevant data is gathered from various sources. This is often the most time-consuming part of the process.
#
# * **Collection:** Data might come from customer relationship management (CRM) systems, website analytics, sales figures, social media, or public datasets.
# * **Cleaning:** Raw data is almost always messy. This step involves correcting errors, handling missing values, and removing duplicate entries.
# * **Preparation (Feature Engineering):** Data is transformed into a format suitable for analysis. This might involve combining certain data points or creating new variables (called "features") that could influence the outcome. For example, instead of just using a customer's birthdate, you might create a feature for their age group.

# %% [markdown]
# ## 3. Building the Predictive Model
# This is where machine learning and statistics come into play. A predictive model is an algorithm that is "trained" on the historical data to find patterns.
#
# The data is typically split into two parts: a **training set** and a **testing set**.
# * The **training set** (usually the larger portion) is fed into the algorithm to teach it the patterns.
# * The **testing set** is used to evaluate how well the model learned. By using data the model has never seen before, you can check if its predictions are accurate.
#
# Common types of models include:
# * **Regression Models:** Used for predicting continuous numerical values, like forecasting sales revenue or a house price.
# * **Classification Models:** Used for predicting a category or a yes/no outcome. For instance, classifying an email as "spam" or "not spam," or determining if a customer will "churn" (leave) or "not churn."
# * **Clustering Models:** Used for grouping data points into natural clusters based on their similarities, often used in customer segmentation.

# %% [markdown]
# ## 4. Deployment and Monitoring
# After a model is trained and tested, it's deployed into a live environment to make real-world predictions. For example, it could be integrated into a company's website to recommend products to users in real-time.
#
# The work doesn't stop there. 🤚🏾
#
# Models must be continuously **monitored** to ensure they remain accurate. Over time, new data might reveal new patterns, and the model may need to be retrained or updated to maintain its predictive power.

# %% [markdown]
# <!-- .slide: data-background="#fdf6e3" data-transition="fade" -->
#
# <h1 style="text-align:center;">Examples of Predictive Analytics</h1>

# %% [markdown]
# #### 1. Customer Churn Prediction in Telecom 📞
#
# - 🎯 **Objective:** Identify customers likely to leave for competitors.
# - 🛠️ **Methods Used:** Analysis of call patterns, service usage, billing history, and customer complaints.
# - ✅ **Outcome:** At-risk customers are flagged, enabling proactive retention strategies such as targeted incentives and offers.

# %% [markdown]
# #### 2. Credit Scoring in Banking 🏦
#
# - 🎯 **Objective:** Assess the probability of loan default among applicants.
# - 🛠️ **Methods Used:** Evaluation of credit history, income level, age, and employment status using predictive models.
# - ✅ **Outcome:** Informed and timely lending decisions, reduced financial risk, and improved bank profitability.

# %% [markdown]
# #### 3. Demand Forecasting in Retail 🛍️
#
# - 🎯 **Objective:** Predict future product demand to optimise inventory levels.
# - 🛠️ **Methods Used:** Analysis of historical sales data, seasonality, promotional campaigns, and economic trends.
# - ✅ **Outcome:** Efficient stock management, minimised waste, and improved product availability during peak periods.

# %% [markdown]
# #### 4. Patient Risk Assessment in Healthcare 🏥
#
# - 🎯 **Objective:** Predict patients at high risk of developing chronic conditions or requiring hospitalisation.
# - 🛠️ **Methods Used:** Analysis of patient records, lab results, and demographic data.
# - ✅ **Outcome:** Early intervention, improved patient outcomes, and better allocation of healthcare resources.

# %% [markdown]
# <h1 style="text-align:center;">Real-Time Stock Price Prediction 📈</h1>
#
# -  **Objective:** Demonstrate predictive analytics on live financial data — from extraction to visualization and a simple forecasting model.
#
# -  **dataset setup:** Live + historical prices for Indian & global tickers (e.g., `NVDA`, `AMD``NVDA`, `INFY.NS`, `^NSEI`, `USDINR=X`, `CL=F`) pulled with **yfinance** (data from 2018 → 2025).
#
# -  **Pipeline:**
#   - **Extraction & tabulation:** Download time-series (Close, Open, High, Low, Volume) and display sample dataframes.
#   - **Merge & feature prep:** Combine tickers (e.g., TCS + INFY + NIFTY) and create lag / volume features for modeling.
#   - **Modeling:** Supervised approach using `scikit-learn` (LinearRegression) with a defined training window.
#   - **Interactive visualization:** Time-series traces plotted with **Plotly** to compare actuals (TCS / INFY / NIFTY) and inspect patterns.

# %% [markdown]
#   “We pull real market data via `yfinance`, prepare time-lagged features, fit a simple linear model to illustrate forecasting mechanics, and use interactive Plotly charts to interpret model fit and limitations.”

# %%
import warnings
warnings.filterwarnings("ignore")
import pandas as pd
from IPython.display import Markdown, display

from IPython.display import HTML, display

# This line formats all floats to 2 decimal places for display
pd.options.display.float_format = '{:.2f}'.format

# %%
pip install yfinance
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import yfinance as yf
import pandas as pd

# Use distinct names for ticker strings
tcs_ticker = "TCS.NS"
infy_ticker = "INFY.NS"
nifty_ticker = "^NSEI"

start_date = "2018-01-01"
end_date = "2025-09-25"

# --- Download data into new DataFrame variables ---
tcs = yf.download(tcs_ticker, start=start_date, end=end_date, progress=False)
infy = yf.download(infy_ticker, start=start_date, end=end_date, progress=False)
nifty = yf.download(nifty_ticker, start=start_date, end=end_date, progress=False)

# --- Format dates (this part was correct) ---
start_date_formatted = pd.to_datetime(start_date).strftime('%d-%B-%Y').lower()
end_date_formatted = pd.to_datetime(end_date).strftime('%d-%B-%Y').lower()

# --- Create headings using the original ticker strings ---
tcs_heading = f"{tcs_ticker.split('.')[0]} ({start_date_formatted} to {end_date_formatted})"
infy_heading = f"{infy_ticker.split('.')[0]} ({start_date_formatted} to {end_date_formatted})"
# A better name for ^NSEI is "Nifty 50"
nifty_heading = f"Nifty 50 ({start_date_formatted} to {end_date_formatted})"
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 import yfinance as yf
#       2 import pandas as pd
#       4 # Use distinct names for ticker strings
#
# ModuleNotFoundError: No module named 'yfinance'

# %%
# --- Print the heading and display the data ---
print(tcs_heading)
print("(Rows,Columns)=",tcs.shape)
display(tcs.head(5))
display(tcs.tail(5))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 # --- Print the heading and display the data ---
# ----> 2 print(tcs_heading)
#       3 print("(Rows,Columns)=",tcs.shape)
#       4 display(tcs.head(5))
#
# NameError: name 'tcs_heading' is not defined

# %%
# --- Print the heading and display the data ---
print(infy_heading)
print("(Rows,Columns)=",infy.shape)
display(infy.head(5))
display(infy.tail(5))
# Out:
# INFY (01-january-2018 to 25-september-2025)
# (Rows,Columns)= (1911, 5)
# Price        Close    High     Low    Open    Volume
# Ticker     INFY.NS INFY.NS INFY.NS INFY.NS   INFY.NS
# Date
# 2018-01-01  429.77  434.32  428.29  431.49   5431340
# 2018-01-02  428.17  433.28  425.38  431.31   6112248
# 2018-01-03  424.67  428.96  423.55  427.67   6846552
# 2018-01-04  422.22  424.55  419.81  424.55   8947614
# 2018-01-05  420.81  426.80  418.31  422.18  11025976
# Price        Close    High     Low    Open    Volume
# Ticker     INFY.NS INFY.NS INFY.NS INFY.NS   INFY.NS
# Date
# 2025-09-18 1540.60 1555.00 1538.50 1550.00   9331945
# 2025-09-19 1540.20 1551.30 1520.10 1544.60  12988129
# 2025-09-22 1499.50 1514.70 1482.00 1482.70  15655204
# 2025-09-23 1497.50 1513.00 1493.00 1493.00   9832164
# 2025-09-24 1494.60 1496.70 1482.70 1487.20   4937004

# %%
# --- Print the heading and display the data ---
print(nifty_heading)
print("(Rows,Columns)=",nifty.shape)
display(nifty.head(5))
display(nifty.tail(5))
# Out:
# Nifty 50 (01-january-2018 to 25-september-2025)
# (Rows,Columns)= (1906, 5)
# Price         Close     High      Low     Open  Volume
# Ticker        ^NSEI    ^NSEI    ^NSEI    ^NSEI   ^NSEI
# Date
# 2018-01-02 10442.20 10495.20 10404.65 10477.55  153400
# 2018-01-03 10443.20 10503.60 10429.55 10482.65  167300
# 2018-01-04 10504.80 10513.00 10441.45 10469.40  174900
# 2018-01-05 10558.85 10566.10 10520.10 10534.25  180900
# 2018-01-08 10623.60 10631.20 10588.55 10591.70  169000
# Price         Close     High      Low     Open  Volume
# Ticker        ^NSEI    ^NSEI    ^NSEI    ^NSEI   ^NSEI
# Date
# 2025-09-18 25423.60 25448.95 25329.75 25441.05  272200
# 2025-09-19 25327.05 25428.75 25286.30 25410.20  380400
# 2025-09-22 25202.35 25331.70 25151.05 25238.10  254500
# 2025-09-23 25169.50 25261.90 25084.65 25209.00  299200
# 2025-09-24 25056.90 25149.85 25027.45 25108.75  244400

# %%
# India
tcs = tcs.reset_index()[['Date','Close','Volume']].rename(columns={'Close':'TCS','Volume':'TCS_vol'})
infy = infy.reset_index()[['Date','Close','Volume']].rename(columns={'Close':'INFY','Volume':'INFY_vol'})
nifty = nifty.reset_index()[['Date','Close','Volume']].rename(columns={'Close':'NIFTY','Volume':'NIFTY_vol'})

# %%
# --- Print the heading and display the data ---
print(tcs_heading)
print("(Rows,Columns)=",tcs.shape)
display(tcs.head(5))
display(tcs.tail(5))
# Out:
# TCS (01-january-2018 to 25-september-2025)
# (Rows,Columns)= (1911, 3)
# Price        Date     TCS  TCS_vol
# Ticker             TCS.NS   TCS.NS
# 0      2018-01-01 1176.52  1351760
# 1      2018-01-02 1170.12  1920290
# 2      2018-01-03 1173.43  1257120
# 3      2018-01-04 1181.64   913082
# 4      2018-01-05 1195.91  1153706
# Price        Date     TCS  TCS_vol
# Ticker             TCS.NS   TCS.NS
# 1906   2025-09-18 3176.70  2633138
# 1907   2025-09-19 3169.20  4901694
# 1908   2025-09-22 3073.80  3634901
# 1909   2025-09-23 3062.40  3177741
# 1910   2025-09-24 3035.40  1625714

# %%
# --- Print the heading and display the data ---
print(infy_heading)
print("(Rows,Columns)=",infy.shape)
display(infy.head(5))
display(infy.tail(5))
# Out:
# INFY (01-january-2018 to 25-september-2025)
# (Rows,Columns)= (1911, 3)
# Price        Date    INFY  INFY_vol
# Ticker            INFY.NS   INFY.NS
# 0      2018-01-01  429.77   5431340
# 1      2018-01-02  428.17   6112248
# 2      2018-01-03  424.67   6846552
# 3      2018-01-04  422.22   8947614
# 4      2018-01-05  420.81  11025976
# Price        Date    INFY  INFY_vol
# Ticker            INFY.NS   INFY.NS
# 1906   2025-09-18 1540.60   9331945
# 1907   2025-09-19 1540.20  12988129
# 1908   2025-09-22 1499.50  15655204
# 1909   2025-09-23 1497.50   9832164
# 1910   2025-09-24 1494.60   4937004

# %%
# --- Print the heading and display the data ---
print(nifty_heading)
print("(Rows,Columns)=",nifty.shape)
display(nifty.head(5))
display(nifty.tail(5))
# Out:
# Nifty 50 (01-january-2018 to 25-september-2025)
# (Rows,Columns)= (1906, 3)
# Price        Date    NIFTY NIFTY_vol
# Ticker               ^NSEI     ^NSEI
# 0      2018-01-02 10442.20    153400
# 1      2018-01-03 10443.20    167300
# 2      2018-01-04 10504.80    174900
# 3      2018-01-05 10558.85    180900
# 4      2018-01-08 10623.60    169000
# Price        Date    NIFTY NIFTY_vol
# Ticker               ^NSEI     ^NSEI
# 1901   2025-09-18 25423.60    272200
# 1902   2025-09-19 25327.05    380400
# 1903   2025-09-22 25202.35    254500
# 1904   2025-09-23 25169.50    299200
# 1905   2025-09-24 25056.90    244400

# %%
# India (TCS, Infosys, Nifty 50)
india_train = tcs.merge(infy, on="Date", how="inner") .merge(nifty, on="Date", how="inner")
india_train_heading = f"TCS INFY NIFTY (merged) ({start_date_formatted} to {end_date_formatted})"
# Quick check
print(india_train_heading)
print(india_train.shape)
display(india_train.head(5))
display(india_train.tail(5))
# Out:
# TCS INFY NIFTY (merged) (01-january-2018 to 25-september-2025)
# (1906, 7)
# Price        Date     TCS  TCS_vol    INFY  INFY_vol    NIFTY NIFTY_vol
# Ticker             TCS.NS   TCS.NS INFY.NS   INFY.NS    ^NSEI     ^NSEI
# 0      2018-01-02 1170.12  1920290  428.17   6112248 10442.20    153400
# 1      2018-01-03 1173.43  1257120  424.67   6846552 10443.20    167300
# 2      2018-01-04 1181.64   913082  422.22   8947614 10504.80    174900
# 3      2018-01-05 1195.91  1153706  420.81  11025976 10558.85    180900
# 4      2018-01-08 1207.12  1242220  430.81   5594690 10623.60    169000
# Price        Date     TCS  TCS_vol    INFY  INFY_vol    NIFTY NIFTY_vol
# Ticker             TCS.NS   TCS.NS INFY.NS   INFY.NS    ^NSEI     ^NSEI
# 1901   2025-09-18 3176.70  2633138 1540.60   9331945 25423.60    272200
# 1902   2025-09-19 3169.20  4901694 1540.20  12988129 25327.05    380400
# 1903   2025-09-22 3073.80  3634901 1499.50  15655204 25202.35    254500
# ...

# %%
# Interactive 2D Plotly time-series with range slider & buttons
import pandas as pd
import plotly.express as px
import plotly.io as pio

pio.renderers.default = "notebook_connected"  # change if needed

# prepare df safely
df = india_train.copy()
if isinstance(df.columns, pd.MultiIndex):
    df.columns = df.columns.get_level_values(0)
if 'Date' not in df.columns:
    df = df.reset_index().rename(columns={df.columns[0]:'Date'})
df['Date'] = pd.to_datetime(df['Date'], errors='coerce')

# pick columns that exist
wanted = ["TCS","INFY","NIFTY"]
available = [c for c in wanted if c in df.columns]
if not available:
    # try fuzzy matches if exact names not present
    cols = [c for c in df.columns if any(w.lower() in str(c).lower() for w in wanted)]
    available = cols[:3]

df_long = df.melt(id_vars='Date', value_vars=available, 
                  var_name='Company', value_name='Closing Price').dropna(subset=['Closing Price'])

fig = px.line(df_long, x='Date', y='Closing Price', color='Company',
              title='TCS, Infosys, Nifty 50')

# enable range slider and selectors + increase chart size
fig.update_layout(
    xaxis=dict(
        rangeselector=dict(
            buttons=list([
                dict(count=1, label="1m", step="month", stepmode="backward"),
                dict(count=3, label="3m", step="month", stepmode="backward"),
                dict(count=6, label="6m", step="month", stepmode="backward"),
                dict(count=1, label="YTD", step="year", stepmode="todate"),
                dict(count=1, label="1y", step="year", stepmode="backward"),
                dict(step="all")
            ])
        ),
        rangeslider=dict(visible=True),
        type="date"
    ),
    hovermode='x unified',
    height=600,   # 👈 increase chart height
    width=900,   # 👈 optional: increase chart width
    margin=dict(l=40, r=40, t=60, b=40)  # adjust margins
)

fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.1.0.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
            import numpy as np
            import pandas as pd
            import matplotlib.pyplot as plt
            from sklearn.linear_model import LinearRegression
            from sklearn.metrics import mean_absolute_percentage_error, mean_squared_error
            import yfinance as yf
            
            def simple_forecast(train_df, col_name, start_pred="2025-01-01", end_pred="2025-09-25"):
                df = train_df[["Date", col_name]].dropna().copy()
                df = df.sort_values("Date").reset_index(drop=True)
            
                # Features: trend + seasonality
                df["t"] = np.arange(len(df))
                df["doy"] = df["Date"].dt.dayofyear
                df["sin_doy"] = np.sin(2*np.pi*df["doy"]/365.25)
                df["cos_doy"] = np.cos(2*np.pi*df["doy"]/365.25)
            
                X = df[["t","sin_doy","cos_doy"]].values
                y = df[col_name].values
                model = LinearRegression().fit(X, y)
            
                # Forecast dates
                future_dates = pd.bdate_range(start=start_pred, end=end_pred)
                t_future = np.arange(len(df), len(df)+len(future_dates))
                future = pd.DataFrame({"Date": future_dates})
                future["t"] = t_future
                future["doy"] = future["Date"].dt.dayofyear
                future["sin_doy"] = np.sin(2*np.pi*future["doy"]/365.25)
                future["cos_doy"] = np.cos(2*np.pi*future["doy"]/365.25)
                future["Predicted"] = model.predict(future[["t","sin_doy","cos_doy"]].values)
            
                return future
            
            # --- Forecast NVDA, AMD, TCS, INFY ---
            
            forecast_tcs  = simple_forecast(india_train, "TCS")
            forecast_infy = simple_forecast(india_train, "INFY")
            
            # --- Download actuals for Jul-Sep 2025 ---
            
            # --- Use already cleaned data (tcs, infy) as actuals ---
            # Restrict to the period Jan–Sep 2025
            
            tcs_actual  = tcs[(tcs["Date"] >= "2025-01-01") & (tcs["Date"] <= "2025-09-25")][["Date","TCS"]].reset_index(drop=True)
            infy_actual = infy[(infy["Date"] >= "2025-01-01") & (infy["Date"] <= "2025-09-25")][["Date","INFY"]].reset_index(drop=True)

# %%
            # --- Plot ---
plt.figure(figsize=(12,6))
plt.plot(forecast_tcs["Date"], forecast_tcs["Predicted"], label="TCS Predicted", color="skyblue")
plt.plot(tcs_actual["Date"], tcs_actual["TCS"], label="TCS Actual", color="navy")
            
            
plt.title("TCS (Predicted vs Actual, Jan–Sep 2025)")
plt.xlabel("Date"); plt.ylabel("Price (INR)")
plt.legend(); plt.grid(True); plt.show()

# %%
# --- Plot ---
plt.figure(figsize=(12,6))
plt.plot(forecast_infy["Date"], forecast_infy["Predicted"], label="INFY Predicted", color="orange")
plt.plot(infy_actual["Date"], infy_actual["INFY"], label="INFY Actual", color="red")

plt.title("Infosys (Predicted vs Actual, Jan–Sep 2025)")
plt.xlabel("Date"); plt.ylabel("Price (INR)")
plt.legend(); plt.grid(True); plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import yfinance as yf
import statsmodels.api as sm

# --- 1) Download data (2022–2024 for training) ---
tickers = {
    "TCS": "TCS.NS",
    "INFY": "INFY.NS",
    "NIFTY": "^NSEI",
    "USDINR": "USDINR=X",
    "OIL": "CL=F",        # Crude Oil Futures
    "SP500": "^GSPC"
}

data = {}
for name, t in tickers.items():
    df = yf.download(t, start="2022-01-01", end="2024-12-31", progress=False)
    data[name] = df[["Close"]].rename(columns={"Close": name})

# Merge into single dataset (prices)
df = pd.concat(data.values(), axis=1).dropna().reset_index()

# --- 2) Compute daily returns ---
returns = df.copy()
for col in tickers.keys():
    returns[col] = returns[col].pct_change()
returns = returns.dropna().reset_index(drop=True)

# --- Helper: regression on returns (with p-value) ---
def run_return_regression(x_col, y_col):
    X = returns[[x_col]]
    y = returns[y_col]

    # add constant for intercept
    X_sm = sm.add_constant(X)
    model = sm.OLS(y, X_sm).fit()

    beta = float(model.params[1])
    intercept = float(model.params[0])
    r2 = float(model.rsquared)
    pval = float(model.pvalues[1])

    # Scatterplot
    plt.figure(figsize=(7,5))
    plt.scatter(X, y, alpha=0.4, label="Daily returns")
    plt.plot(X, model.predict(X_sm), color="red",
             label=f"Fit line (β={beta:.3f}, R²={r2:.3f}, p={pval:.3g})")
    plt.xlabel(x_col); plt.ylabel(y_col)
    plt.title(f"{y_col} vs {x_col} (returns)")
    plt.legend(); plt.grid(True); plt.show()

    # Nicely formatted text output
    print(f"Regression Results: {y_col} ~ {x_col}")
    print(f"  Beta (slope): {beta:.6f}")
    print(f"  Intercept:    {intercept:.6f}")
    print(f"  R²:           {r2:.6f}")
    print(f"  p-value:      {pval:.6g}")

    return beta, intercept, r2, pval

# %%
print("\nNIFTY vs SP500")
print(run_return_regression("SP500", "NIFTY"))
# Out:
# NIFTY vs SP500
# Regression Results: NIFTY ~ SP500
#   Beta (slope): 0.167614
#   Intercept:    0.000393
#   R²:           0.044395
#   p-value:      1.34566e-08
# (0.16761360444826304, 0.0003929894281119985, 0.04439487284195465, 1.3456635994496131e-08)

# %%
print("\nInfosys vs S&P500")
print(run_return_regression("SP500", "INFY"))
# Out:
# Infosys vs S&P500
# Regression Results: INFY ~ SP500
#   Beta (slope): 0.192733
#   Intercept:    0.000165
#   R²:           0.018913
#   p-value:      0.000230265
# (0.192733170226863, 0.00016537452367997152, 0.018913063257220752, 0.00023026450838645285)

# %%
print("\nInfosys vs NIFTY")
print(run_return_regression("NIFTY", "INFY"))
# Out:
# Infosys vs NIFTY
# Regression Results: INFY ~ NIFTY
#   Beta (slope): 0.998426
#   Intercept:    -0.000218
#   R²:           0.321193
#   p-value:      8.07237e-62
# (0.9984256283470307, -0.00021796007679520716, 0.3211930208978526, 8.072365675514158e-62)

# %%
print("\nTCS vs S&P500")
print(run_return_regression("SP500", "TCS"))
# Out:
# TCS vs S&P500
# Regression Results: TCS ~ SP500
#   Beta (slope): 0.214685
#   Intercept:    0.000195
#   R²:           0.032318
#   p-value:      1.35647e-06
# (0.214685156240188, 0.0001947904829768376, 0.03231826712797403, 1.3564716316637932e-06)

# %%
print("\nTCS vs NIFTY")
print(run_return_regression("NIFTY", "TCS"))
# Out:
# TCS vs NIFTY
# Regression Results: TCS ~ NIFTY
#   Beta (slope): 0.827760
#   Intercept:    -0.000103
#   R²:           0.304045
#   p-value:      5.89585e-58
# (0.8277596263973769, -0.00010347634206830236, 0.304045252128038, 5.895849493670644e-58)

# %% [markdown]
# <h1 style="text-align:center;">Thank You</h1>
